# %%
import requests
import base64
import json
import pandas as pd
from config import APIkey
from config import APISecret

# %%
# Set up your API keys and secrets
consumer_key = APIkey
consumer_secret = APISecret

# Encode the API keys and secrets for use in the request header
bearer_token = base64.b64encode(f'{consumer_key}:{consumer_secret}'.encode())

# %%
# Set up OAuth request headers
headers = {
    'Authorization': f'Basic {bearer_token.decode()}',
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

# Set up the request body
data = 'grant_type=client_credentials'

# Send the request to the Twitter API to get an access token
response = requests.post('https://api.twitter.com/oauth2/token', headers=headers, data=data)

# Extract the access token from the response
access_token = response.json()['access_token']

# Set up the request headers for the timeline request
headers = {
    'Authorization': f'Bearer {access_token}'
}

response
# Out:
# <Response [200]>

# %%
# Set up the request parameters for the timeline request
params = {
    'screen_name': 'elonmusk',  # User to request
    'count': 200,  # The maximum number of tweets to return (up to a maximum of 3200)
    'exclude_replies': True,  # Do not include replies in the timeline
    'include_rts': False,  # Do not include retweets in the timeline
}

# Send the request to the Twitter API to get the user timeline
response = requests.get('https://api.twitter.com/1.1/statuses/user_timeline.json', headers=headers, params=params)

# Extract the timeline from the response    
timeline = response.json()

# %%
len(timeline)

timeline
# Out:
# [{'created_at': 'Tue Dec 20 00:36:52 +0000 2022',
#   'id': 1604999237099716609,
#   'id_str': '1604999237099716609',
#   'text': 'Stats on Twitter World Cup\nhttps://t.co/y91SB99eKZ',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/y91SB99eKZ',
#      'expanded_url': 'https://blog.twitter.com/en_us/topics/events/2022/2022-World-Cup-Insights',
#      'display_url': 'blog.twitter.com/en_us/topics/e…',
#      'indices': [27, 50]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2053,
#   'favorite_count': 21674,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Dec 19 01:29:14 +0000 2022',
#   'id': 1604650028999405568,
#   'id_str': '1604650028999405568',
#   'text': 'Those who want power are the ones who least deserve it',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 89407,
#   'favorite_count': 895776,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Dec 19 00:23:02 +0000 2022',
#   'id': 1604633369626652672,
#   'id_str': '1604633369626652672',
#   'text': 'Elvis is in the building https://t.co/dppDnK1WBt',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/dppDnK1WBt',
#      'expanded_url': 'https://twitter.com/mtaibbi/status/1604613292491538432',
#      'display_url': 'twitter.com/mtaibbi/status…',
#      'indices': [25, 48]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1604613292491538432,
#   'quoted_status_id_str': '1604613292491538432',
#   'quoted_status': {'created_at': 'Sun Dec 18 23:03:15 +0000 2022',
#    'id': 1604613292491538432,
#    'id_str': '1604613292491538432',
#    'text': '1.THREAD: Twitter Files Supplemental',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 38271276,
#     'id_str': '38271276',
#     'name': 'Matt Taibbi',
#     'screen_name': 'mtaibbi',
#     'location': 'New Jersey, USA',
#     'description': 'Author of GRIFTOPIA, THE DIVIDE, THE BUSINESS SECRETS OF DRUG DEALING, and HATE INC. https://t.co/I7ld6ZAti9',
#     'url': 'https://t.co/I7ld6ZAti9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/I7ld6ZAti9',
#         'expanded_url': 'http://taibbi.substack.com',
#         'display_url': 'taibbi.substack.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/I7ld6ZAti9',
#         'expanded_url': 'http://taibbi.substack.com',
#         'display_url': 'taibbi.substack.com',
#         'indices': [85, 108]}]}},
#     'protected': False,
#     'followers_count': 1634215,
#     'friends_count': 4034,
#     'listed_count': 11610,
#     'created_at': 'Wed May 06 20:41:55 +0000 2009',
#     'favourites_count': 1922,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 25233,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0E1111',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1603844439226650663/UfW1lmpB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1603844439226650663/UfW1lmpB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38271276/1619220153',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'D9D9D9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 19009,
#    'favorite_count': 57195,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 16080,
#   'favorite_count': 115942,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 23:43:31 +0000 2022',
#   'id': 1604623424164282368,
#   'id_str': '1604623424164282368',
#   'text': 'As the saying goes, be careful what you wish, as you might get it',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 43459,
#   'favorite_count': 525585,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 23:20:33 +0000 2022',
#   'id': 1604617643973124097,
#   'id_str': '1604617643973124097',
#   'text': 'Should I step down as head of Twitter? I will abide by the results of this poll.',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 256496,
#   'favorite_count': 529161,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 23:17:27 +0000 2022',
#   'id': 1604616863673208832,
#   'id_str': '1604616863673208832',
#   'text': 'Going forward, there will be a vote for major policy changes. My apologies. Won’t happen again.',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 20934,
#   'favorite_count': 396866,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 18:02:47 +0000 2022',
#   'id': 1604537674878042112,
#   'id_str': '1604537674878042112',
#   'text': 'Duel in the Desert.\nCouldn’t ask for a better game. Incredible play by 🇦🇷 &amp; 🇫🇷 !!!! https://t.co/XUZxjymAx0',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1604537148992110599,
#      'id_str': '1604537148992110599',
#      'indices': [88, 111],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604537148992110599/img/Rou-txT-T53oMcyp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604537148992110599/img/Rou-txT-T53oMcyp.jpg',
#      'url': 'https://t.co/XUZxjymAx0',
#      'display_url': 'pic.twitter.com/XUZxjymAx0',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604537674878042112/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1920, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1604537148992110599,
#      'id_str': '1604537148992110599',
#      'indices': [88, 111],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604537148992110599/img/Rou-txT-T53oMcyp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604537148992110599/img/Rou-txT-T53oMcyp.jpg',
#      'url': 'https://t.co/XUZxjymAx0',
#      'display_url': 'pic.twitter.com/XUZxjymAx0',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604537674878042112/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1920, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [9, 16],
#       'duration_millis': 4468,
#       'variants': [{'bitrate': 950000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604537148992110599/vid/480x852/QeDvWAZaUH17WcpQ.mp4?tag=16'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604537148992110599/vid/320x568/APuziyi8oyEKkrUL.mp4?tag=16'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1604537148992110599/pl/yylac_yF1ogzbSky.m3u8?tag=16&container=fmp4'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604537148992110599/vid/720x1280/-gGgPX5CINA7oE_c.mp4?tag=16'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604537148992110599/vid/1080x1920/2uFb0LzYxJB9dOEd.mp4?tag=16'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 43606,
#   'favorite_count': 513729,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 17:39:24 +0000 2022',
#   'id': 1604531789686530048,
#   'id_str': '1604531789686530048',
#   'text': '3 - 3 WOW!!! https://t.co/asxw78EgPn',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1604531684610916354,
#      'id_str': '1604531684610916354',
#      'indices': [13, 36],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604531684610916354/img/XeYXzlrmK5HxUyhO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604531684610916354/img/XeYXzlrmK5HxUyhO.jpg',
#      'url': 'https://t.co/asxw78EgPn',
#      'display_url': 'pic.twitter.com/asxw78EgPn',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604531789686530048/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1604531684610916354,
#      'id_str': '1604531684610916354',
#      'indices': [13, 36],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604531684610916354/img/XeYXzlrmK5HxUyhO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604531684610916354/img/XeYXzlrmK5HxUyhO.jpg',
#      'url': 'https://t.co/asxw78EgPn',
#      'display_url': 'pic.twitter.com/asxw78EgPn',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604531789686530048/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 6033,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1604531684610916354/pl/PsrY0-YtTJ8q49at.m3u8?tag=16&container=fmp4'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604531684610916354/vid/1920x1080/ae8Lwn5LmFfL-AsW.mp4?tag=16'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604531684610916354/vid/1280x720/TF5WVLEB2GILmm_x.mp4?tag=16'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604531684610916354/vid/480x270/Wor3bvG9cCP0K5dv.mp4?tag=16'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604531684610916354/vid/640x360/Po-3EkrK6Uj8O1dZ.mp4?tag=16'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 26525,
#   'favorite_count': 444663,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Sun Dec 18 16:55:22 +0000 2022',
#   'id': 1604520708570517504,
#   'id_str': '1604520708570517504',
#   'text': '24,400 tweets per second for France’s goal, highest ever for World Cup!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 37064,
#   'favorite_count': 510428,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 16:54:13 +0000 2022',
#   'id': 1604520419515662337,
#   'id_str': '1604520419515662337',
#   'text': 'Well done France! 🇫🇷🇫🇷🇫🇷\nEvenly-matched game!! https://t.co/dH1CPRRno9',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1604520305237671937,
#      'id_str': '1604520305237671937',
#      'indices': [47, 70],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604520305237671937/img/jxeVdRmK6UiCpzqU.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604520305237671937/img/jxeVdRmK6UiCpzqU.jpg',
#      'url': 'https://t.co/dH1CPRRno9',
#      'display_url': 'pic.twitter.com/dH1CPRRno9',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604520419515662337/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1604520305237671937,
#      'id_str': '1604520305237671937',
#      'indices': [47, 70],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604520305237671937/img/jxeVdRmK6UiCpzqU.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604520305237671937/img/jxeVdRmK6UiCpzqU.jpg',
#      'url': 'https://t.co/dH1CPRRno9',
#      'display_url': 'pic.twitter.com/dH1CPRRno9',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604520419515662337/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 7666,
#       'variants': [{'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604520305237671937/vid/1920x1080/868rUsyrQ-VZjbTP.mp4?tag=16'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1604520305237671937/pl/XVlRH7GBqpT-T0BJ.m3u8?tag=16&container=fmp4'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604520305237671937/vid/480x270/86QjEW0HxLgyp1AP.mp4?tag=16'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604520305237671937/vid/640x360/zUfwCndj44XAAW3e.mp4?tag=16'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604520305237671937/vid/1280x720/000QBlDqos4_2bja.mp4?tag=16'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 8846,
#   'favorite_count': 145657,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 16:05:44 +0000 2022',
#   'id': 1604508220206321667,
#   'id_str': '1604508220206321667',
#   'text': 'Super exciting World Cup!\n🇦🇷 ahead 2-0 at halftime.\nCan 🇫🇷 come back?',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 15229,
#   'favorite_count': 349997,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 15:27:49 +0000 2022',
#   'id': 1604498679234273286,
#   'id_str': '1604498679234273286',
#   'text': 'Great goal by Argentina! 🇦🇷🇦🇷🇦🇷 https://t.co/WIs9ocfPcz',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1604498542793572353,
#      'id_str': '1604498542793572353',
#      'indices': [32, 55],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604498542793572353/img/ueq8S84l2VkO9hrf.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604498542793572353/img/ueq8S84l2VkO9hrf.jpg',
#      'url': 'https://t.co/WIs9ocfPcz',
#      'display_url': 'pic.twitter.com/WIs9ocfPcz',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604498679234273286/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1604498542793572353,
#      'id_str': '1604498542793572353',
#      'indices': [32, 55],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604498542793572353/img/ueq8S84l2VkO9hrf.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604498542793572353/img/ueq8S84l2VkO9hrf.jpg',
#      'url': 'https://t.co/WIs9ocfPcz',
#      'display_url': 'pic.twitter.com/WIs9ocfPcz',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604498679234273286/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 3333,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604498542793572353/vid/1280x720/vsdvdEMG3cJSyRwY.mp4?tag=16'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1604498542793572353/pl/xh64XDWkw6Q9dk_W.m3u8?tag=16&container=fmp4'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604498542793572353/vid/640x360/Ni1NmFZx-5x56kpZ.mp4?tag=16'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604498542793572353/vid/1920x1080/alOVdN9HlTW6ZwJV.mp4?tag=16'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604498542793572353/vid/480x270/vn862hIyJAMUZsH_.mp4?tag=16'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 32205,
#   'favorite_count': 382640,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 18 14:53:59 +0000 2022',
#   'id': 1604490162976698368,
#   'id_str': '1604490162976698368',
#   'text': 'At World Cup right now https://t.co/CG7zMMxSjE',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1604490050338799618,
#      'id_str': '1604490050338799618',
#      'indices': [23, 46],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604490050338799618/img/-YlyxVbhLNDSlBSi.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604490050338799618/img/-YlyxVbhLNDSlBSi.jpg',
#      'url': 'https://t.co/CG7zMMxSjE',
#      'display_url': 'pic.twitter.com/CG7zMMxSjE',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604490162976698368/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1920, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1604490050338799618,
#      'id_str': '1604490050338799618',
#      'indices': [23, 46],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1604490050338799618/img/-YlyxVbhLNDSlBSi.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1604490050338799618/img/-YlyxVbhLNDSlBSi.jpg',
#      'url': 'https://t.co/CG7zMMxSjE',
#      'display_url': 'pic.twitter.com/CG7zMMxSjE',
#      'expanded_url': 'https://twitter.com/elonmusk/status/1604490162976698368/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1920, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [9, 16],
#       'duration_millis': 5833,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1604490050338799618/pl/vsqRLRhdrXsw08Ro.m3u8?tag=16&container=fmp4'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604490050338799618/vid/320x568/fwo5kQlhPwLhgE8f.mp4?tag=16'},
#        {'bitrate': 950000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604490050338799618/vid/480x852/mftzjGrhL9rjRw8s.mp4?tag=16'},
#        {'bitrate': 10368000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604490050338799618/vid/1080x1920/5Z6TA9XtXn3NKEvD.mp4?tag=16'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1604490050338799618/vid/720x1280/S0TwU9aHB5RvkFn8.mp4?tag=16'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 40640,
#   'favorite_count': 689985,
#   'favorited': False,
# ...
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1603843072915148800,
#   'quoted_status_id_str': '1603843072915148800',
#   'quoted_status': {'created_at': 'Fri Dec 16 20:02:41 +0000 2022',
#    'id': 1603843072915148800,
#    'id_str': '1603843072915148800',
#    'text': 'Should real-time doxxing be allowed on Twitter?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1137701,
#     'id_str': '1137701',
#     'name': 'David Sacks',
#     'screen_name': 'DavidSacks',
#     'location': 'San Francisco',
#     'description': 'VC @craft_ventures Bestie @theallinpod Founder @getcallin',
#     'url': 'https://t.co/VWe3GFbxF2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VWe3GFbxF2',
#         'expanded_url': 'http://sacks.substack.com',
#         'display_url': 'sacks.substack.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 527536,
#     'friends_count': 2952,
#     'listed_count': 6207,
#     'created_at': 'Wed Mar 14 04:14:58 +0000 2007',
#     'favourites_count': 32685,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 9067,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1398157893774413825/vQ-FwRtP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1398157893774413825/vQ-FwRtP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1137701/1667750503',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2423,
#    'favorite_count': 5333,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 3533,
#   'favorite_count': 41549,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Dec 16 17:28:07 +0000 2022',
#   'id': 1603804175858429952,
#   'id_str': '1603804175858429952',
#   'text': 'And soon, ladies &amp; gentlemen, the coup de grâce',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 35634,
#   'favorite_count': 348219,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'fr'},
#  {'created_at': 'Fri Dec 16 07:53:39 +0000 2022',
#   'id': 1603659604906213376,
#   'id_str': '1603659604906213376',
#   'text': 'Twitter right now is 🔥🔥🔥🔥',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 48425,
#   'favorite_count': 670881,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Dec 16 04:34:25 +0000 2022',
#   'id': 1603609466301059073,
#   'id_str': '1603609466301059073',
#   'text': 'Unsuspend accounts who doxxed my exact location in real-time',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 19443,
#   'favorite_count': 90151,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Dec 16 03:56:48 +0000 2022',
#   'id': 1603600001057185792,
#   'id_str': '1603600001057185792',
#   'text': 'Unsuspend accounts who doxxed my exact location in real-time',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10323,
#   'favorite_count': 83780,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Dec 16 02:22:25 +0000 2022',
#   'id': 1603576251125362688,
#   'id_str': '1603576251125362688',
#   'text': 'I love Barbara Streisand lol',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122354863,
#    'friends_count': 155,
#    'listed_count': 105983,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 16205,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 21540,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 7799,
#   'favorite_count': 121005,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %%
# set up lists to hold response data
tweetCreated = []
tweetText = []
screenName = []

# loop through tweets, make requests and parse
for tweet in timeline:
    tweetCreated.append(tweet['created_at'])
    tweetText.append(tweet['text'])
    screenName.append(tweet['user']['screen_name'])


tweetText
# screenName
# tweetCreated
# Out:
# ['Stats on Twitter World Cup\nhttps://t.co/y91SB99eKZ',
#  'Those who want power are the ones who least deserve it',
#  'Elvis is in the building https://t.co/dppDnK1WBt',
#  'As the saying goes, be careful what you wish, as you might get it',
#  'Should I step down as head of Twitter? I will abide by the results of this poll.',
#  'Going forward, there will be a vote for major policy changes. My apologies. Won’t happen again.',
#  'Duel in the Desert.\nCouldn’t ask for a better game. Incredible play by 🇦🇷 &amp; 🇫🇷 !!!! https://t.co/XUZxjymAx0',
#  '3 - 3 WOW!!! https://t.co/asxw78EgPn',
#  '24,400 tweets per second for France’s goal, highest ever for World Cup!',
#  'Well done France! 🇫🇷🇫🇷🇫🇷\nEvenly-matched game!! https://t.co/dH1CPRRno9',
#  'Super exciting World Cup!\n🇦🇷 ahead 2-0 at halftime.\nCan 🇫🇷 come back?',
#  'Great goal by Argentina! 🇦🇷🇦🇷🇦🇷 https://t.co/WIs9ocfPcz',
#  'At World Cup right now https://t.co/CG7zMMxSjE',
#  'Follow The World Cup on Twitter!\nhttps://t.co/SaTzwDzBuR',
#  'Hallelujah!! https://t.co/i2FyvXPIHO',
#  'True creation eventually becomes independent of its creator. Evolution takes the original product far from its orig… https://t.co/rS8EOZ1ElI',
#  'Congrats to SpaceX Team on 3 perfect orbital launches within 36 hours!!!',
#  'Live launch video https://t.co/9GtonaQiUw',
#  'https://t.co/94I61oMYFs',
#  'Twitter will start incorporating mute &amp; block signals from Blue Verified (not Legacy Blue) as downvotes',
#  'The people have spoken.\n\nAccounts who doxxed my location will have their suspension lifted now. https://t.co/MFdXbEQFCe',
#  'Second launch today https://t.co/gUnyyUlZSi',
#  'Spaces is back',
#  'KABOOM 💥💥💥💥💥 https://t.co/TS3jFZ51VR',
#  'So inspiring to see the newfound love of freedom of speech by the press 🥰',
#  'Meanwhile, Twitter usage (by real humans) once again reaches all-time highs',
#  'Great questions https://t.co/3HueYswz6o',
#  'And soon, ladies &amp; gentlemen, the coup de grâce',
#  'Twitter right now is 🔥🔥🔥🔥',
#  'Unsuspend accounts who doxxed my exact location in real-time',
#  'Unsuspend accounts who doxxed my exact location in real-time',
#  'I love Barbara Streisand lol']
